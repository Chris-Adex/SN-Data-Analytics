# %% [markdown]
#  <span style="font-family:times new roman">
#
#  ### STEPS INVOLVED
#
# 1. I logged into my account on GitHub at **Github.com**.
#
#
# 2. After logging in, I clicked on a green tab (create new repository).
#
#
# 3. On the new repository page, I entered **SN-Data-Analytics** as my repository's name and clicked on create repository.
#
#
# 4. On the repository's page, I clicked on create a new file.
#
#
# 5. I entered **First Assignment** as the file's name followed by **'/'** to make it a folder.
#
#
# 6. I entered **readme.md** on the next tab as the new file's name and clicked on commit file at the bottom of the page.
#
#
# 7. After creating the folder, I clicked on code and copied the SSH link {git@github.com:Chris-Adex/SN-Data-Analytics.git} to the clipboard.
#
#       ***Note: Prior to this, I already created and added my public SSH key to my GitHub account.***
#
#
# 8. I launched my already installed Git Bash on my PC to clone the repository.
#
#
# 9. I launched my Git Bash and followed the following processes:
#
#
#     a. cd desktop (to change the directory to save the repository to desktop).
#     b. git clone git@github.com:Chris-Adex/SN-Data-Analytics.git (to clone my repository to the desktop)
#
#
# 10. I launched my jupyter notebook afterwards and navigate to my repository folder to create an empty notebook file (python 3) and save it.
#
#
# 11. I opened  my Git Bash to update the files in my github repository with the following commands:
#
#
#     a. cd desktop
#     b. cd SN-Data-Analytics
#     c. git add .
#     d. git commit -m "my first commit"
#     e. git push origin main
#
#
# 12. After this, the files on my github repository are updated.
#
# ### PROBLEMS ENCOUNTERED
#
# 1. I was unable to create a folder in the repository I created on github.
#
#
# 2. I was unable to push an empty notebook into the repository.
#
#
# ### SOLUTIONS
#
# 1. To create a folder, I simply clicked on create a new file in the repository and whille entering the name I added **'/'** at the end to automatically create a folder. I also added a readme.md to be able to save the folder.
#
#
# 2. To push an empty notebook into the repository, I simply followed the intructions in step 11 under **steps involved** above.
# </span>
